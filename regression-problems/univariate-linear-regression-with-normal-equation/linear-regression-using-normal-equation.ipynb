# %%
import pandas as pd
import numpy as np
import matplotlib as mat
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import statsmodels.api as stats
import sklearn as sklearn
from sklearn import preprocessing
from sklearn import datasets
from sklearn.linear_model import LinearRegression

# %%
print("pandas version:", pd.__version__)
print("numpy version:", np.__version__)
print("matplotlib version:", mat.__version__)
print("statsmodels version:", stats.__version__)
print("sklearn version:", sklearn.__version__)
# Out:
# pandas version: 1.0.5
# numpy version: 1.18.5
# matplotlib version: 3.3.0
# statsmodels version: 0.11.1
# sklearn version: 0.23.1

# %%
dataframe = pd.read_csv('linear.csv')
print("Shape of the dataset: {}".format(dataframe.shape))
print("------------------------------")
print(dataframe.describe())
print("------------------------------")
# Out:
# Shape of the dataset: (300, 2)
# ------------------------------
#                 x           y
# count  300.000000  300.000000
# mean    50.936667   51.205051
# std     28.504286   29.071481
# min      0.000000   -3.467884
# 25%     27.000000   25.676502
# 50%     53.000000   52.170557
# 75%     73.000000   74.303007
# max    100.000000  105.591837
# ------------------------------

# %%
X_featured = dataframe["x"]
Y_observed = dataframe["y"]

def standardize_data(data):
    return (data - np.mean(data)) / (np.std(data))
## END

def normalize_data(data):
    return (data - np.mean(data)) / (np.max(data) - np.min(data))
## END

X_rescaled = standardize_data(X_featured)
print(X_rescaled.describe())
# Out:
# count    3.000000e+02
# mean    -2.368476e-17
# std      1.001671e+00
# min     -1.789969e+00
# 25%     -8.411599e-01
# 50%      7.250772e-02
# 75%      7.753289e-01
# max      1.724138e+00
# Name: x, dtype: float64

# %%
plt.scatter(X_rescaled, Y_observed, color = "orange", label = 'data')
plt.xlabel('X_rescaled', fontsize = 18)
plt.ylabel('Y_observed', fontsize = 18)
plt.legend(fontsize = 14)
plt.show()

# %%
# # Don't forget - adding ones to the x matrix
feature_matrix = np.c_[np.ones((len(X_rescaled),1)), X_rescaled]

# # calculate linear regression parameters theta using the normal equation
# The normal equation formula is given by : theta = [inv(X' * X) * (X' * Y)]
theta = np.linalg.inv(feature_matrix.T.dot(feature_matrix)).dot(feature_matrix.T).dot(Y_observed)

# theta[0] is intercept, theta[1] is slope. This is determined by the column order of matrix.
print("Intercept: {}".format(theta[0]))
print("Coefficient for feature_matirx: {}".format(theta[1]))
# Out:
# Intercept: 51.205051098276684
# Coefficient for feature_matirx: 28.86467635885324

# %%
Y_predicted = theta[0]*feature_matrix[:,0] + theta[1]*feature_matrix[:,1]

# %%
plt.scatter(X_rescaled, Y_observed, color = "orange", label = 'data')
plt.plot(X_rescaled, Y_predicted, color = "black", label = 'prediction')
plt.xlabel('X_rescaled', fontsize = 18)
plt.ylabel('Y_observed', fontsize = 18)
plt.legend(fontsize = 14)
plt.show()
