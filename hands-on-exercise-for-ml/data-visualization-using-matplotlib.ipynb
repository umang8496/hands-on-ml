# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib as matplot
import pandas as pd
import numpy as np

# %%
X = np.linspace(0, 10, 15)
X
# Out:
# array([ 0.        ,  0.71428571,  1.42857143,  2.14285714,  2.85714286,
#         3.57142857,  4.28571429,  5.        ,  5.71428571,  6.42857143,
#         7.14285714,  7.85714286,  8.57142857,  9.28571429, 10.        ])

# %%
Y = X**2
Y
# Out:
# array([  0.        ,   0.51020408,   2.04081633,   4.59183673,
#          8.16326531,  12.75510204,  18.36734694,  25.        ,
#         32.65306122,  41.32653061,  51.02040816,  61.73469388,
#         73.46938776,  86.2244898 , 100.        ])

# %%
plt.plot(X, Y)
plt.xlabel('X (floating-point values)', fontsize = 15)
plt.ylabel('Y (squares of X)', fontsize = 15)
plt.title('Sample Plot', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Sample Plot')

# %% [markdown]
# ## Subplot
# This is used for creating the multiplots on the same canvas.

# %%
#Argument takes - (1: Number of rows | 2: Number of columns | 1: The plot number we are refering)
plt.subplot(1, 2, 1)
plt.plot(X, Y, color = 'red')

plt.subplot(1, 2, 2)
plt.plot(Y, X, color = 'black')

# %% [markdown]
# ## Object oriented method

# %%
fig = plt.figure()
#getting blank axes (canvas). add_axes takes an arguement of left, bottom, width and height
axes = fig.add_axes([0.1,0.5,0.8,0.8])
#Ploting the values
axes.plot(X, Y)
#set labels
axes.set_xlabel('X (floating-point values)', fontsize = 15)
axes.set_ylabel('Y (squares of X)', fontsize = 15)
axes.set_title('Plot usign Object', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Plot usign Object')

# %% [markdown]
# ## Lets try to create canvas and see how their position change with respect to their values

# %%
#Both created axes will merge as their values are same
fig = plt.figure()
#
axes1 = fig.add_axes([0.1, 0.5, 0.8, 0.8], label="axes1")
axes2 = fig.add_axes([0.1, 0.5, 0.8, 0.8], label="axes2")

# %%
# The first one is 0.1 from left side where as axes2 is 0.2 from the left
# axes1 : 0.5 from the bottom whereas axes2: 0.2 from the bottom.
# Same width and height
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.5, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.2, 0.8, 0.8])

# %%
# The first one is 0.1 from left side where as axes2 is 0.4 from the left
# axes1 : 0.5 from the bottom whereas axes2: 0.6 from the bottom.
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.5, 0.8, 0.8])
axes2 = fig.add_axes([0.4, 0.6, 0.4, 0.5])

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.5, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.9, 0.3, 0.2])

axes1.plot(X, Y, color='black')
axes1.set_xlabel('X1')
axes1.set_ylabel('Y1')
axes1.set_title('Outer_plot')

axes2.plot(X, Y, color='red')
# axes2.set_xlabel('X2')
# axes2.set_ylabel('Y2')
axes2.set_title('Inner_plot')
# Out:
# Text(0.5, 1.0, 'Inner_plot')

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
#To fix overlapping
plt.tight_layout()
axes
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
# This 'axes' is iterable
fig, axes = plt.subplots(nrows=1, ncols=2)
for i in axes:
    i.plot(X, Y)

# %%
fig,axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(X, Y)
axes[1].plot(Y, X)

# %% [markdown]
# ## Figure Size / Aspect ratio / DPI

# %%
fig = plt.figure(figsize=(5, 5))
axes1 = fig.add_axes([0.1, 0.5, 0.8, 0.8])
axes1.plot(X, Y)
axes1.set_xlabel('X1')
axes1.set_ylabel('Y1')
axes1.set_title('Outer_plot')
# Out:
# Text(0.5, 1.0, 'Outer_plot')

# %%
fig = plt.figure(figsize=(10, 5))
axes1 = fig.add_axes([0.1, 0.5, 0.8, 0.8])
axes1.plot(X, Y)
axes1.set_xlabel('X1')
axes1.set_ylabel('Y1')
axes1.set_title('Outer_plot')
# Out:
# Text(0.5, 1.0, 'Outer_plot')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,3))
axes[0].plot(X, Y)
axes[1].plot(X, Y)

# %% [markdown]
# ## Save Images

# %%
fig
# fig.savefig("<path-and-name-of-the-image-file>", dpi=200)

# %% [markdown]
# ## Legend

# %%
fig = plt.figure(figsize=(10,5))
axes1 = fig.add_axes([0.1,0.5,0.8,0.8])
axes1.plot(X, X**2,label='x-square')
axes1.plot(X, X**3,label='x-cube')
#loc is used to select location for legend
axes1.legend(loc=0)

# %% [markdown]
# ## Setting linewidth, transparency & linestyle
# 'linestyle' supported values are '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted'

# %%
fig = plt.figure(figsize=(10,5))
axes1 = fig.add_axes([0.1, 0.5, 0.8, 0.8])
axes1.plot(X, Y, color='green', linewidth=5)

# %%
fig = plt.figure(figsize=(10,5))
axes1 = fig.add_axes([0.1, 0.5, 0.8, 0.8])
axes1.plot(X, Y, color='green', linewidth=5, alpha=0.5)

# %%
fig = plt.figure(figsize=(10,5))
axes1 = fig.add_axes([0.1, 0.5, 0.8, 0.8])
axes1.plot(X, Y, color='green', linewidth=5, linestyle='--')

# %%
fig = plt.figure(figsize=(10,5))
axes1 = fig.add_axes([0.1, 0.5, 0.8, 0.8])
axes1.plot(X, Y, color='green', linewidth=5, linestyle='dotted')

# %% [markdown]
# ## Marker

# %%
#To markout each point
fig = plt.figure(figsize=(10,5))
axes1 = fig.add_axes([0.1,0.5,0.8,0.8])
axes1.plot(X, Y,color='green',
                linewidth=2,
                marker='o',
                markersize=10,
                markerfacecolor='red',
                markeredgewidth=3,
                markeredgecolor='yellow')

# %% [markdown]
# ## Limit the plot

# %%
fig = plt.figure(figsize=(15, 10))
axes1 = fig.add_axes([0.1,0.5,0.8,0.8], label="axes1")
axes1.plot(X, Y, color='red', linewidth=2)

# %%
# To get part of the above graph say x from 0 to 2
fig = plt.figure(figsize=(15, 10))
axes2 = fig.add_axes([0.1,0.5,0.8,0.8], label="axes2")
axes2.plot(X, Y, color='red', linewidth=2)
axes2.set_xlim([0,2])
# Out:
# (0.0, 2.0)

# %%
fig = plt.figure(figsize=(15, 10))
axes3 = fig.add_axes([0.1,0.5,0.8,0.8], label="axes3")
axes3.plot(X, Y, color='red', linewidth=2)
axes1.set_xlim([0,2])
axes1.set_ylim([0,10])
# Out:
# (0.0, 10.0)

# %% [markdown]
# ## https://matplotlib.org/users/index.html
# ## https://matplotlib.org/3.3.0/tutorials/introductory/usage.html#sphx-glr-tutorials-introductory-usage-py

# %% [markdown]
# ## Bivariate plotting with pandas

# %%
reviews = pd.read_csv("./datasets/winemag-data_first150k.csv", index_col=0)
reviews.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %% [markdown]
# ### Scatter plot
# The simplest bivariate plot is the lowly scatter plot.
# A simple scatter plot simply maps each variable of interest to a point in two-dimensional space.

# %%
reviews[reviews['price'] < 100].sample(100).plot.scatter(x='price', y='points')
# Out:
# <AxesSubplot:xlabel='price', ylabel='points'>

# %% [markdown]
# This plot shows us that price and points are weakly correlated: that is, that more expensive wines do generally earn more points when reviewed.
# Note that in order to make effective use of this plot, we had to downsample our data, taking just 100 points from the full set.
# This is because naive scatter plots do not effectively treat points which map to the same place.
#
# For example, if two wines, costing 100 dollars, get a rating of 90, then the second one is overplotted onto the first one, and we add just one point to the plot.
# This isn't a problem if it happens just a few times.
# But with enough points the distribution starts to look like a shapeless blob, and you lose the forest for the trees

# %%
reviews[reviews['price'] < 100].plot.scatter(x='price', y='points')
# Out:
# <AxesSubplot:xlabel='price', ylabel='points'>

# %% [markdown]
# Because of their weakness to overplotting, scatter plots work best with relatively small datasets, and with variables which have a large number of unique values.
#
# There are a few ways to deal with overplotting.
# We've already demonstrated one way: sampling the points.
# Another interesting way to do this that's built right into pandas is to use our next plot type, a hexplot.

# %% [markdown]
# ### Hexplot
# A hex plot aggregates points in space into hexagons, and then colors those hexagons based on the values within them.

# %%
reviews[reviews['price'] < 100].plot.hexbin(x='price', y='points', gridsize=15)
# Out:
# <AxesSubplot:xlabel='price', ylabel='points'>

# %% [markdown]
# The data in this plot is directly comparable with that in the scatter plot from earlier, but the story it tells us is very different.
# From this hexplot we can see that the bottles of wine reviewed by Wine Magazine cluster around 87.5 points and around $20.
# (note: the x-axis is points, but is missing from the chart due to a bug)
#
# We did not see this effect by looking at the scatter plot, because too many similarly-priced, similarly-scoring wines were overplotted.
# By doing away with this problem, this hexplot presents us a much more useful view of the dataset.
# Hexplots and scatter plots can by applied to combinations of interval variables and/or ordinal categorical variables.

# %% [markdown]
# ### Stacked plots
# Scatter plots and hex plots are new. But we can also use the simpler plots we saw in the last notebook.
# The easiest way to modify them to support another visual variable is by using stacking.
# A stacked chart is one which plots the variables one on top of the other.

# %%
months= [x for x in range(1,13)]
mortgage= [700, 700, 700, 800, 800, 800, 850, 850, 850, 850, 850, 850]
utilities= [500, 300, 380, 200, 600, 550, 310, 620, 290, 320, 440, 400]
repairs= [100, 120, 100, 150, 850, 80, 120, 220, 240, 50, 60, 150]

df = pd.DataFrame([months, mortgage, utilities, repairs])

plt.plot([],[], color='blue', label='mortgage')
plt.plot([],[], color='orange', label='utilities')
plt.plot([],[], color='brown', label='repairs')

plt.stackplot(months, mortgage, utilities, repairs, colors=['blue', 'orange', 'brown'])
plt.legend()
plt.title('Household Expenses')
plt.xlabel('Months of the year')
plt.ylabel('Cost')
plt.show()

# %%
df.plot.area()
# Out:
# <AxesSubplot:>

# %%
df.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df.plot.line()
# Out:
# <AxesSubplot:>
